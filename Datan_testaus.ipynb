# %%
import pandas as pd

df = pd.read_csv('GPSData.csv')
df.head()
# Out:
#    Time (s)  Latitude (°)  Longitude (°)  Altitude (m)  Altitude WGS84 (m)  \
# 0  0.210700     64.966037      25.613784     18.893231           36.399998
# 1  1.610534     64.966037      25.613784    -17.506767            0.000000
# 2  3.041460     64.966016      25.613998     13.315450           30.822266
# 3  4.041342     64.966023      25.614032     16.905783           34.412598
# 4  5.041936     64.966017      25.614014     17.641132           35.147949
#
#    Speed (m/s)  Direction (°)  Distance (km)  Horizontal Accuracy (m)  \
# 0          NaN            NaN       0.000000                56.020000
# 1         0.00       0.000000       0.010313                56.020000
# 2         1.07      60.599998       0.012067                 6.492342
# 3         0.80      24.200001       0.013102                 4.336436
# 4         0.17      24.200001       0.014685                 4.337386
#
#    Vertical Accuracy (m)  Satellites
# 0               1.000000         0.0
# ...

# %%
df = pd.read_csv('combined.csv')
df.head()
# Out:
#    Time (s)  Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 0  0.033491                       0.361473                       0.056772
# 1  0.038551                       0.418941                       0.064452
# 2  0.043604                       0.367447                       0.017955
# 3  0.048607                       0.327732                      -0.030915
# 4  0.053610                       0.280094                       0.023838
#
#    Linear Acceleration z (m/s^2)  Latitude (°)  Longitude (°)  Altitude (m)  \
# 0                       0.212620     64.966037      25.613784     18.893231
# 1                       0.274851     64.966037      25.613784    -17.506767
# 2                       0.261076     64.966016      25.613998     13.315450
# 3                       0.237305     64.966023      25.614032     16.905783
# 4                       0.165927     64.966017      25.614014     17.641132
#
# ...

# %%
import pandas as pd

# Read CSV files
df_a = pd.read_csv("Kiihtyvyys.csv")
df_m = pd.read_csv("Uusi_GPS.csv")

combined = pd.concat(
    [df_a.reset_index(drop=True),
     df_m.reset_index(drop=True)],
    axis=1
)

combined.to_csv("combined.csv", index=False)
